# %%
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.1

# %% [markdown]
# ### a)

# %%
data = pd.read_csv("../../01 Modulunterlagen/SW01/child.csv", sep=",", index_col=0)

# %%
data.head()
# Out:
#                 Average.disposable.income  Children.in.poor.homes  \
# Australia                       20.813221               11.791352
# Austria                         22.162446                6.166094
# Belgium                         21.401153                9.974720
# Canada                          25.606245               15.057585
# Czech Republic                  10.849270               10.270000
#
#                 Educational.Deprivation  Overcrowding  \
# Australia                           2.2     19.700000
# Austria                             0.6     34.014601
# Belgium                             1.0     12.614505
# Canada                              2.1           NaN
# Czech Republic                      1.2     58.899347
#
#                 Poor.environmental.conditions  Average.mean.literacy.score  \
# Australia                           10.500000                       520.00
# Austria                             20.154186                       502.00
# ...

# %% [markdown]
# ### b)

# %%
data.shape
# Out:
# (30, 21)

# %% [markdown]
# ### c)

# %%
data.describe()
# Out:
#        Average.disposable.income  Children.in.poor.homes  \
# count                  30.000000               30.000000
# mean                   18.847713               12.372193
# std                     7.597219                5.592696
# min                     3.839462                2.740000
# 25%                    16.617877                8.901475
# 50%                    21.107187               11.659053
# 75%                    22.642722               16.091953
# max                    34.241822               24.590000
#
#        Educational.Deprivation  Overcrowding  Poor.environmental.conditions  \
# count                30.000000     26.000000                      24.000000
# mean                  2.673333     31.950163                      25.217498
# std                   3.315370     21.132363                       7.483096
# min                   0.400000     10.326503                      10.500000
# ...

# %%
data.mean()
# Out:
# Average.disposable.income         18.847713
# Children.in.poor.homes            12.372193
# Educational.Deprivation            2.673333
# Overcrowding                      31.950163
# Poor.environmental.conditions     25.217498
# Average.mean.literacy.score      496.317000
# Literacy.inequality                1.665085
# Youth.NEET.rate                    7.377778
# Low.birth.weight                   6.643333
# Infant.mortality                   5.446667
# Breastfeeding.rates               86.027586
# Vaccination.rates..pertussis.     93.775862
# Vaccination.rates.measles.        91.517241
# Physical.activity                 20.134615
# Mortality.rates                   24.598966
# Suicide.rates                      6.856272
# Smoking                           16.512500
# Drunkenness                       15.225000
# Teenage.births                    15.500000
# Bullying                          10.979167
# Liking.school                     27.172000
# dtype: float64

# %%
data.median()
# Out:
# Average.disposable.income         21.107187
# Children.in.poor.homes            11.659053
# Educational.Deprivation            1.500000
# Overcrowding                      21.574977
# Poor.environmental.conditions     25.487116
# Average.mean.literacy.score      501.335000
# Literacy.inequality                1.682739
# Youth.NEET.rate                    6.200000
# Low.birth.weight                   6.750000
# Infant.mortality                   4.200000
# Breastfeeding.rates               91.000000
# Vaccination.rates..pertussis.     95.800000
# Vaccination.rates.measles.        94.000000
# Physical.activity                 19.300000
# Mortality.rates                   23.150000
# Suicide.rates                      6.784772
# Smoking                           16.600000
# Drunkenness                       14.550000
# Teenage.births                    10.600000
# Bullying                           9.650000
# Liking.school                     25.600000
# dtype: float64

# %% [markdown]
# ### d)

# %%
data.index
# Out:
# Index(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Slovak Republic', 'Spain', 'Sweden', 'Switzerland', 'Turkey',
#        'United Kingdom', 'United States'],
#       dtype='object')

# %%
help(data.index)
# Out:
# Help on Index in module pandas.core.indexes.base object:
#
# class Index(pandas.core.base.IndexOpsMixin, pandas.core.base.PandasObject)
#  |  Index(data=None, dtype=None, copy=False, name=None, fastpath=None, tupleize_cols=True, **kwargs)
#  |
#  |  Immutable ndarray implementing an ordered, sliceable set. The basic object
#  |  storing axis labels for all pandas objects.
#  |
#  |  Parameters
#  |  ----------
#  |  data : array-like (1-dimensional)
#  |  dtype : NumPy dtype (default: object)
#  |      If dtype is None, we find the dtype that best fits the data.
#  |      If an actual dtype is provided, we coerce to that dtype if it's safe.
#  |      Otherwise, an error will be raised.
#  |  copy : bool
#  |      Make a copy of input ndarray
#  |  name : object
#  |      Name to be stored in the index
#  |  tupleize_cols : bool (default: True)
#  |      When True, attempt to create a MultiIndex if possible
#  |
#  |  See Also
#  |  ---------
# ...

# %%
dataindex = data.index

# %%
dataindex.contains('Netherlands')
# Out:
# True

# %%
dataindex.contains('China')
# Out:
# False

# %% [markdown]
# mit data.describe() erhalte ich alle Spaltennamen oder data.columns

# %% [markdown]
# ### e)

# %%
data.columns
# Out:
# Index(['Average.disposable.income', 'Children.in.poor.homes',
#        'Educational.Deprivation', 'Overcrowding',
#        'Poor.environmental.conditions', 'Average.mean.literacy.score',
#        'Literacy.inequality', 'Youth.NEET.rate', 'Low.birth.weight',
#        'Infant.mortality', 'Breastfeeding.rates',
#        'Vaccination.rates..pertussis.', 'Vaccination.rates.measles.',
#        'Physical.activity', 'Mortality.rates', 'Suicide.rates', 'Smoking',
#        'Drunkenness', 'Teenage.births', 'Bullying', 'Liking.school'],
#       dtype='object')

# %%
data["Drunkenness"].sort_values(ascending=False).head(5)
# Out:
# Denmark           24.8
# Finland           22.4
# United Kingdom    22.1
# Poland            19.9
# Canada            18.8
# Name: Drunkenness, dtype: float64

# %% [markdown]
# ### f)

# %%
data["Infant.mortality"].nsmallest().head(1)
# Out:
# Iceland    2.3
# Name: Infant.mortality, dtype: float64

# %% [markdown]
# ### g)

# %%
physmean = data["Physical.activity"].mean()
data["Physical.activity"].loc[data["Physical.activity"] < physmean].sort_values(ascending=True)
# Out:
# Switzerland       13.1
# France            13.5
# Portugal          14.6
# Italy             15.1
# Luxembourg        15.2
# Greece            15.5
# Norway            15.6
# Sweden            16.4
# Germany           17.0
# Poland            17.3
# Mexico            18.1
# United Kingdom    18.7
# Belgium           19.1
# Hungary           19.5
# Austria           19.6
# Turkey            20.0
# Name: Physical.activity, dtype: float64

# %% [markdown]
# # 1.2
# ### a)

# %%
fuel = pd.read_csv("../../01 Modulunterlagen/SW01/d.fuel.dat", sep=",", index_col=0)

# %%
fuel.head()
# Out:
#    weight  mpg   type
# X
# 1    2560   33  Small
# 2    2345   33  Small
# 3    1845   37  Small
# 4    2260   32  Small
# 5    2440   32  Small

# %% [markdown]
# ### b)

# %%
fuel.loc[5]
# Out:
# weight     2440
# mpg          32
# type      Small
# Name: 5, dtype: object

# %% [markdown]
# ### c)

# %%
fuel.loc[1:5]
# Out:
#    weight  mpg   type
# X
# 1    2560   33  Small
# 2    2345   33  Small
# 3    1845   37  Small
# 4    2260   32  Small
# 5    2440   32  Small

# %% [markdown]
# ### d)

# %%
fuel["mpg"].mean()
# Out:
# 24.583333333333332

# %% [markdown]
# ### e)

# %%
fuel["mpg"].loc[7:22].mean()
# Out:
# 27.75

# %% [markdown]
# ### f)

# %%
t_kml = fuel["mpg"]*1.6093/3.789

# %%
t_kml.head()
# Out:
# X
# 1    14.016073
# 2    14.016073
# 3    15.714991
# 4    13.591343
# 5    13.591343
# Name: mpg, dtype: float64

# %%
t_kg = fuel["weight"]*0.45359
t_kg.head()
# Out:
# X
# 1    1161.19040
# 2    1063.66855
# 3     836.87355
# 4    1025.11340
# 5    1106.75960
# Name: weight, dtype: float64

# %% [markdown]
# ### g)

# %%
print(t_kml.mean(), "&", t_kg.mean())
# Out:
# 10.441266385149994 & 1315.7889916666668

# %%
print(t_kml.mean())
print(t_kg.mean())
# Out:
# 10.441266385149994
# 1315.7889916666668

# %% [markdown]
# # 1.3

# %%
bauer = pd.Series([2.1,2.4,2.8,3.1,4.2,4.9,5.1,6.0,6.4,7.3,10.8,12.5,13.0,13.7,14.8,17.6,19.6,
23.0,25.0,35.2,39.6])

# %%
bauer.head()
# Out:
# 0    2.1
# 1    2.4
# 2    2.8
# 3    3.1
# 4    4.2
# dtype: float64

# %% [markdown]
# ### a)

# %%
bauer.sum()
# Out:
# 269.1

# %%
bauer2 = bauer**2
bauer2.sum()
# Out:
# 5729.27

# %% [markdown]
# ### b)

# %%
bauer.size
# Out:
# 21

# %%
mean = (bauer.sum() / bauer.size)
print(mean)
# Out:
# 12.814285714285715

# %%
var = (bauer2.sum() / bauer.size) - mean**2
print(var)
# Out:
# 108.61646258503401

# %%
sigma = np.sqrt(var)
print (sigma)
# Out:
# 10.421922211618835

# %%
bauer.std()
# Out:
# 10.679292378911898

# %% [markdown]
# ### c)

# %%
bauersort = bauer.sort_values(ascending=False)
print(bauersort)
# Out:
# 20    39.6
# 19    35.2
# 18    25.0
# 17    23.0
# 16    19.6
# 15    17.6
# 14    14.8
# 13    13.7
# 12    13.0
# 11    12.5
# 10    10.8
# 9      7.3
# 8      6.4
# 7      6.0
# 6      5.1
# 5      4.9
# 4      4.2
# 3      3.1
# 2      2.8
# 1      2.4
# 0      2.1
# dtype: float64

# %%
bauersort.size / 2
# Out:
# 10.5

# %%
print(bauersort[10])
print(bauersort[11])
# Out:
# 10.8
# 12.5

# %% [markdown]
# ### d)

# %%
print(bauer.mean())
print(bauer.std())
print(bauer.median())
# Out:
# 12.814285714285715
# 10.679292378911898
# 10.8

# %% [markdown]
# ### e)

# %%
empbauer = (bauer - bauer.mean())/bauer.std()
print(empbauer)
# Out:
# 0    -1.003277
# 1    -0.975185
# 2    -0.937729
# 3    -0.909638
# 4    -0.806635
# 5    -0.741087
# 6    -0.722359
# 7    -0.638084
# 8    -0.600628
# 9    -0.516353
# 10   -0.188616
# 11   -0.029429
# 12    0.017390
# 13    0.082938
# 14    0.185941
# 15    0.448130
# 16    0.635409
# 17    0.953782
# 18    1.141060
# 19    2.096180
# 20    2.508192
# dtype: float64

# %%
print(np.round(empbauer.mean(), 12))
print(empbauer.std())
# Out:
# -0.0
# 1.0

# %% [markdown]
# # 1.4
# ### a)

# %%
geysir = pd.read_csv("../../01 Modulunterlagen/SW01/geysir.dat", sep=" ", index_col=0)

# %%
geysir.head()
# Out:
#    Tag  Zeitspanne  Eruptionsdauer
# 1    1          78             4.4
# 2    1          74             3.9
# 3    1          68             4.0
# 4    1          76             4.0
# 5    1          80             3.5

# %%
plt.subplot(221)
geysir["Zeitspanne"].plot(kind="hist", edgecolor="black")
plt.xlabel("10 Klassen")

plt.subplot(222)
geysir["Zeitspanne"].plot(kind="hist",bins=20,edgecolor="black")
plt.xlabel("20 Klassen")

plt.subplot(223)
geysir["Zeitspanne"].plot(kind="hist",bins=np.arange(41,107,11),edgecolor="black")
plt.xlabel("Klassengrenzen 41, 52 , 63, 74 , 85, 96")

plt.show()

# %% [markdown]
# - häufigste Ausbrüche in der Zeitspanne zwischen 70-85 Minuten.
# - Plot 3 ist nicht "aussagekräftig" bzw. sagt aus, dass die Wahl der Grenzen wichtig ist.

# %% [markdown]
# ### b)

# %%
geysir["Eruptionsdauer"].describe()
# Out:
# count    107.000000
# mean       3.460748
# std        1.036299
# min        1.700000
# 25%        2.300000
# 50%        3.800000
# 75%        4.300000
# max        4.900000
# Name: Eruptionsdauer, dtype: float64

# %%
plt.subplot(221)
geysir["Eruptionsdauer"].plot(kind="hist",bins=5,edgecolor="black")
plt.xlabel("5 Klassen")

plt.subplot(222)
geysir["Eruptionsdauer"].plot(kind="hist",bins=10,edgecolor="black")
plt.xlabel("10 Klassen")

plt.subplot(223)
geysir["Eruptionsdauer"].plot(kind="hist",bins=20,edgecolor="black")
plt.xlabel("20 Klassen")

plt.subplot(224)
geysir["Eruptionsdauer"].plot(kind="hist",bins=30,edgecolor="black")
plt.xlabel("30 Klassen")

plt.show()

# %% [markdown]
# ### c)

# %%
geysir["Eruptionsdauer"].plot(kind="hist",edgecolor="black",density=True,cumulative=True)
plt.xlabel("Eruptionsdauer")
# Out:
# Text(0.5, 0, 'Eruptionsdauer')

# %% [markdown]
# - höchstens 2min ca. 20%
# - 60% längste Dauer: ca. 3.8min
